# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
pan = Image.open("../datasets/panda.jpg")

# %%
pan_small = pan.resize((350, 233))

# %%
pan_np = np.array(pan_small)

# %%
pan_np.shape
# Out:
# (233, 350, 3)

# %%
plt.imshow(pan_np)

# %%
height, width, channels = pan_np.shape

# %%
images = np.array([pan_np])

# %%
images.shape
# Out:
# (1, 233, 350, 3)

# %%
plt.imshow(images[0])
