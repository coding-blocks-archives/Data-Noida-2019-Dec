# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
pan = Image.open("../datasets/iron.jpg")

# %%
pan_small = pan.resize((350, 233))

# %%
pan_np = np.array(pan_small)

# %%
pan_np.shape
# Out:
# (233, 350, 3)

# %%
plt.imshow(pan_np)

# %%
height, width, channels = pan_np.shape

# %%
images = np.array([pan_np])

# %%
images.shape
# Out:
# (1, 233, 350, 3)

# %%
plt.imshow(images[0])

# %%
fil = np.array([[0, 0, 0], [0, 9, 0], [0, 0, 0]])

# %%
red = pan_np[:, :, 0]

# %%
red.shape, padded.shape
# Out:
# ((233, 350), (235, 352))

# %%
padded = np.pad(red, 1)

# %%
result = np.zeros_like(red)

# %%
for r in range(red.shape[0]):
    for c in range(red.shape[1]):
        cut = padded[r:r+3, c:c+3]
        result[r, c] = np.abs((fil * cut).mean())

# %%
plt.imshow(result, cmap="gray")

# %%
plt.imshow(red, cmap="gray")
