# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
im = Image.open("cb.png")

# %%
cb = np.array(im)

# %%
plt.imshow(cb[:, :, 3], cmap="gray")

# %%
from PIL import Image
im = Image.open("../lecture_03/panda.jpg")

panda = np.array(im)

plt.imshow(panda)

# %%
cb.shape
# Out:
# (189, 454, 4)

# %%
panda.shape
# Out:
# (720, 1280, 3)

# %%
panda_cut = panda[:cb.shape[0], -cb.shape[1]:]

# %%
plt.imshow(panda_cut)

# %%
for i in range(cb.shape[0]):
    for j in range(cb.shape[1]):
        if cb[i, j, 3] > 0:
            panda_cut[i, j] = cb[i, j, :3]

# %%
plt.imshow(panda)

# %%
chacha = Image.fromarray(panda)

with open("panda_cb.jpg", "wb") as pn:
    chacha.save(pn)
